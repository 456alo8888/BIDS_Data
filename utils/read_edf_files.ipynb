# %%
# !pip install mne

# %%
import mne

# Đọc EDF file
# raw = mne.io.read_raw_edf("/mnt/disk1/aiotlab/hieupc/New_CBraMod/BIDS/bids_testing/sub-0003/eeg/sub-0003_task-rest_eeg.edf", preload=True)
raw = mne.io.read_raw_edf("/mnt/disk1/aiotlab/hieupc/New_CBraMod/BIDS/Test_EDF/CMH/FA5550A0_1-1+.edf", preload=True)

print(raw.info.keys())
print(raw.info.get("subject_info"))

# Chọn riêng channel Fp1
# raw_pick = raw.copy().pick_channels(['Fp1'])

# Hiển thị với scale phù hợp (ví dụ 100 µV cho EEG)
raw.plot(
    scalings={'eeg': 100e-6},  # đặt scale cố định: 100 microvolt
    n_channels=20,             # chỉ hiển thị 20 kênh/lần
    duration=2000,             # hiển thị 10 giây dữ liệu
    show=True,
    block=True
)
# Out:
# Extracting EDF parameters from /mnt/disk1/aiotlab/hieupc/New_CBraMod/BIDS/Test_EDF/CMH/FA5550A0_1-1+.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 51499  =      0.000 ...   102.998 secs...
# dict_keys(['acq_pars', 'acq_stim', 'ctf_head_t', 'description', 'dev_ctf_t', 'dig', 'experimenter', 'utc_offset', 'device_info', 'file_id', 'highpass', 'hpi_subsystem', 'kit_system_id', 'helium_info', 'line_freq', 'lowpass', 'meas_date', 'meas_id', 'proj_id', 'proj_name', 'subject_info', 'xplotter_layout', 'gantry_angle', 'bads', 'chs', 'comps', 'events', 'hpi_meas', 'hpi_results', 'projs', 'proc_history', 'custom_ref_applied', 'sfreq', 'dev_head_t', 'ch_names', 'nchan'])
# <subject_info | his_id: 01, sex: 0, last_name: NGUYEN_THI_LAN_ANH_1>
# <MNEBrowseFigure size 800x800 with 4 Axes>
# <MNEBrowseFigure size 800x800 with 4 Axes>

# %%
import mne

# Đọc EDF file
raw = mne.io.read_raw_edf("/mnt/disk1/aiotlab/hieupc/New_CBraMod/BIDS/bids_testing/sub-0003/eeg/sub-0003_task-rest_eeg.edf", preload=True)
# raw = mne.io.read_raw_edf("/mnt/disk1/aiotlab/hieupc/New_CBraMod/BIDS/Test_EDF/CMH/FA5550A0_1-1+.edf", preload=True)

print(raw.info.keys())
print(raw.info.get("subject_info"))

# Chọn riêng channel Fp1
# raw_pick = raw.copy().pick_channels(['Fp1'])

# Hiển thị với scale phù hợp (ví dụ 100 µV cho EEG)
raw.plot(
    scalings={'eeg': 100e-6},  # đặt scale cố định: 100 microvolt
    n_channels=20,             # chỉ hiển thị 20 kênh/lần
    duration=2000,             # hiển thị 10 giây dữ liệu
    show=True,
    block=True
)
# Out:
# Extracting EDF parameters from /mnt/disk1/aiotlab/hieupc/New_CBraMod/BIDS/bids_testing/sub-0003/eeg/sub-0003_task-rest_eeg.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 51499  =      0.000 ...   102.998 secs...
# dict_keys(['acq_pars', 'acq_stim', 'ctf_head_t', 'description', 'dev_ctf_t', 'dig', 'experimenter', 'utc_offset', 'device_info', 'file_id', 'highpass', 'hpi_subsystem', 'kit_system_id', 'helium_info', 'line_freq', 'lowpass', 'meas_date', 'meas_id', 'proj_id', 'proj_name', 'subject_info', 'xplotter_layout', 'gantry_angle', 'bads', 'chs', 'comps', 'events', 'hpi_meas', 'hpi_results', 'projs', 'proc_history', 'custom_ref_applied', 'sfreq', 'dev_head_t', 'ch_names', 'nchan'])
# <subject_info | his_id: sub-0003, sex: 0, last_name: sub-0003>
# <MNEBrowseFigure size 800x800 with 4 Axes>
# <MNEBrowseFigure size 800x800 with 4 Axes>

# %%
import mne

# Đọc EDF file
raw = mne.io.read_raw_edf("/mnt/disk1/aiotlab/hieupc/New_CBraMod/BIDS/bids_testing/sub-0003/eeg/sub-0003_task-rest_eeg.edf", preload=True)
# raw = mne.io.read_raw_edf("/mnt/disk1/aiotlab/hieupc/New_CBraMod/BIDS/Test_EDF/CMH/FA5550A0_1-1+.edf", preload=True)

print(raw.info.keys())
print(raw.info.get("subject_info"))

# Chọn riêng channel Fp1
# raw_pick = raw.copy().pick_channels(['Fp1'])

# Hiển thị với scale phù hợp (ví dụ 100 µV cho EEG)
raw.plot(
    scalings={'eeg': 100e-6},  # đặt scale cố định: 100 microvolt
    n_channels=20,             # chỉ hiển thị 20 kênh/lần
    duration=2000,             # hiển thị 10 giây dữ liệu
    show=True,
    block=True
)
# Out:
# Extracting EDF parameters from /mnt/disk1/aiotlab/hieupc/New_CBraMod/BIDS/bids_testing/sub-0003/eeg/sub-0003_task-rest_eeg.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 51499  =      0.000 ...   102.998 secs...
# dict_keys(['acq_pars', 'acq_stim', 'ctf_head_t', 'description', 'dev_ctf_t', 'dig', 'experimenter', 'utc_offset', 'device_info', 'file_id', 'highpass', 'hpi_subsystem', 'kit_system_id', 'helium_info', 'line_freq', 'lowpass', 'meas_date', 'meas_id', 'proj_id', 'proj_name', 'subject_info', 'xplotter_layout', 'gantry_angle', 'bads', 'chs', 'comps', 'events', 'hpi_meas', 'hpi_results', 'projs', 'proc_history', 'custom_ref_applied', 'sfreq', 'dev_head_t', 'ch_names', 'nchan'])
# <subject_info | his_id: sub-0003, sex: 0, last_name: sub-0003>
# <MNEBrowseFigure size 800x800 with 4 Axes>
# <MNEBrowseFigure size 800x800 with 4 Axes>

# %%
import mne
raw = mne.io.read_raw_edf("/mnt/disk1/aiotlab/hieupc/New_CBraMod/BIDS/bids_testing/sub-0001/eeg/sub-0001_task-rest_eeg.edf", preload=True)
data = raw.get_data()
print(data.min(), data.max())  # Check signal range
# Out:
# Extracting EDF parameters from /mnt/disk1/aiotlab/hieupc/New_CBraMod/BIDS/bids_testing/sub-0001/eeg/sub-0001_task-rest_eeg.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 33499  =      0.000 ...    66.998 secs...
# -12.0029 0.006972846875715698

# %%
import mne
raw = mne.io.read_raw_edf("/mnt/disk1/aiotlab/hieupc/New_CBraMod/BIDS/bids_testing/sub-0001/eeg/sub-0001_task-rest_eeg_anon.edf", preload=True)
data = raw.get_data()
print(data.min(), data.max())  # Check signal range
# Out:
# Extracting EDF parameters from /mnt/disk1/aiotlab/hieupc/New_CBraMod/BIDS/bids_testing/sub-0001/eeg/sub-0001_task-rest_eeg_anon.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 33499  =      0.000 ...    66.998 secs...
# -12.0029 0.006972846875715698
